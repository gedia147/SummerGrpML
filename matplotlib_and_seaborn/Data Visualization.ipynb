# %%
#Colab users uncomment this code
#File for this notebook is IRIS.csv

# %%
"""
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
"""

# %%
"""
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)
"""

# %%
"""
downloaded = drive.CreateFile({'id':'enter_id'}) # replace the id with id of file you want to access
downloaded.GetContentFile('IRIS.csv')
"""

# %% [markdown]
# # DATA VISUALIZATION
# <hr style="height:5px;border-width:2;color:gray">

# %% [markdown]
# ## INTRODUCTION

# %% [markdown]
# Data Visualization is the third and final topic of Data Analysis that we'll be covering. Data visualization is the graphical representation of information and data. It refers to techniques used to communicate insights from data through visual representation. It's always easier to look at a line plot to understand a trend, than looking at rows and rows of data. Making informative visualizations (sometimes called plots) is one of the most important tasks in data analysis.

# %% [markdown]
# Every good visual must have the following four qualities:
# <ul>
#     <li><b>Truthfulness</b>: Your plots must always accurately show what the data actually says. Using techniques like changing axis scale to suit your needs, and showing something misleading like only the convenient part of the data in the plot is wrong.</li>
#     <li><b>Beauty</b>: Your plots must be appealing to the eye. Beautiful plots catch the audience attention and convey what you are trying to say.</li>
#     <li><b>Functionality</b>: You should plot the right plot for the right kind of data so that the functionality of your plot is maximum.</li>
#     <li><b>Insightfulmess</b>: This is probably the most important quality a visual must have, at least for an ML engineer. Your visual must be insightful and must reveal new information, trends, patterns, anomalies et. which lie hidden in a table of data.</li>

# %% [markdown]
# You might be wondering how this visualization is relevant for ML. That's where EDA steps in. We'll discuss about EDA at the end of this notebook.

# %% [markdown]
# In this notebook you'll be learning <b>matplotlib</b> the goto python library for plotting and visualization. We'll also take a brief look at <b>pandas plot</b> and <b>seaborn</b> and use them to plot some commonly used plots. If you see later on, seaborn and pandas plot make your life a lot easier while plotting, but to customize the plots as per your requirements you need matplotlib.<br><br>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <b>Note:<br>
#     seaborn, pandas plot and especially matplotlib are vast topics and ones that are impossible to cover completely in this notebook. Take this notebook as an introduction and like numpy and pandas learn more by going through the documentation and Google searches. However you don't need to go through them right now. You need to use the documentation as and when required (Same goes for the links provided in the notebook). While doing your own projects, if you get stuck, most of the times your problems will be solved in a single Google search.</b>
# </div>

# %% [markdown]
# <hr style="height:2px;border-width:2;color:gray">

# %% [markdown]
# ## MATPLOTLIB

# %% [markdown]
# matplotlib is a desktop plotting package designed for creating (mostly two dimensional) publication-quality plots.<br>
# <code>matplotlib.pyplot</code> is a state-based interface to matplotlib. It provides a MATLAB-like way of plotting.<br>
# matplotlib like other libraries we've dealt with so far already comes with jupyter and colab. If you are unable to import the libraries, they can be installed like the previous ones.

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <b>Note:</b> While plotting it is always preferable to write all the commands related to one plot in one cell to avoid unecessary problems.
# </div>

# %% [markdown]
# matplotlib follows an Object Oriented Approach to plotting while matplotlib.pyplot is a collection of command style functions that make matplotlib work like MATLAB. However we can use object oriented techniques here too.<br>
# <code>matplotlib.pyplot</code> is generally imported with the alias <code>plt</code>.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Understanding terminologies

# %% [markdown]
# Take a look at this image to get to know how different parts of a chart are named in matplotlib(<a href = "https://matplotlib.org/_images/anatomy.png">Link for Colab users</a>)
# ![anatomy.jpg](attachment:anatomy.jpg)

# %% [markdown]
# ### Figures and Axes<br>
# <b>Figure</b>: The entire figure which may contain one or more Axes is called the Figure object.<br>
# <b>Axes</b>: The Axes object is used to distinctly identify a plot. It may contain 2 (in 2D) or 3 (in 3D) Axis objects.<br>
# <b>Axis</b>: The Axis object refers to numer-line like objects.<br><br>
# A figure may contain a single plot or many subplots. The figure object is used to access the entire figure. In case the figure has many subplots, then each subplot can be accessed using the Axes object (Note the difference between <b>Axes</b> and <b>Axis</b>).<br>
# So if you have a figure which has many subplots, you would use the Axes object to set titles to each subplot separately and use the Figure object to set a title to the entire figure.

# %% [markdown]
# ### <code>plt.plot()</code>

# %% [markdown]
# <code>plt.plot()</code> plots y values against x values in the form of a line plot. (x and y must have same dimensions)

# %%
x = np.arange(1,11)
y = x**2
plt.plot(x, y)

# %% [markdown]
# If you provide a single array as argument, then they are considered as y values and plotted against their indices

# %%
#plt.figure() is used to create a new empty figure so that the new plots don't go back to your old plot.
#plt always refers to the last plotted figure
plt.figure()
y = np.arange(1,11)
plt.plot(y)

# %% [markdown]
# You can also plot multiple lines with a single plot command with different formatting as shown.

# %%
plt.figure()

x1 = np.linspace(0,10,100)
x2 = x1
y1 = np.sin(x1)
y2 = np.cos(x2)

plt.plot(x1, y1, "x--k", x2, y2, "o-r")

# %% [markdown]
# Check this <a href = "https://matplotlib.org/api/_as_gen/matplotlib.pyplot.plot.html#matplotlib.pyplot.plot">link</a> for all kinds of formatting features you can apply to line plots.

# %% [markdown]
# ### Figures and subplots

# %% [markdown]
# As we have already seen, <code>plt.figure()</code> is used to create a new empty figure.

# %%
fig = plt.figure() #Creates an empty figure

# %%
plt.plot([1,2,3,4], [5,10,5,10])

# %% [markdown]
# Multiple subplots can be created in a single figure using <code>plt.subplots()</code>

# %%
fig, axes = plt.subplots(2,2) #2 rows and 2 columns

#Here fig can be used to access the entire figure. axes is a 2x2 numpy array storing the axes objects for each subplot.
#axes[i][j] makes changes to the subplot in ith row and jth column (0 indexed)

axes[0,0].plot([1,2,3,4], [5,10,5,10])
axes[0,1].plot([1,2,3,4], [1,2,3,4])
axes[1,0].plot(np.random.randn(50).cumsum(), 'k--')
axes[1,1].plot(np.linspace(-1,1,21), abs(np.linspace(-1,1,21)))

# %% [markdown]
# subplots also has different attributes e.g, sharex and sharey which can be set to True if you want the plots to have same x-axis or y-axis respectively. Check out the documentation for more info.

# %% [markdown]
# The spacing between subplots can be adjusted using <code>plt.subplots_adjust()</code>. Read more about it <a href = "https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.subplots_adjust.html">Here</a>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>Note:</b><br>
#     The <b>current figure</b> and <b>current axes</b> can be obtained using <code><b>plt.gcf()</b></code> and <code><b>plt.gca()</b></code> respectively.
# </div>

# %% [markdown]
# ### <code>plt.scatter()</code>
# This command creates a scatter plot with markers of varying size and figure.

# %%
plt.figure()

#This function necessarily requires both x and y values
x = np.linspace(-10,11,30)
y = x**2 + np.random.randint(-10,10,30)
plt.scatter(x, y)

# %% [markdown]
# The size of the markers can be changed based on a third list and in a similar way color of the scatter points can also be changed.

# %%
plt.figure()

#This function necessarily requires both x and y values
x = np.linspace(-10,11,30)
y = x**2 + np.random.randint(-10,10,30)
size = np.random.randint(1,50,30)
plt.scatter(x, y, s = size)

# %% [markdown]
# Checkout the <a href = "https://matplotlib.org/3.2.1/api/_as_gen/matplotlib.pyplot.scatter.html">link</a> for more information on various kinds of formatting options in scatter plots.

# %% [markdown]
# ### Customizing a plot

# %% [markdown]
# Most of the times, just plotting values may not be enough. You need to make the plot presentable and understandable by adding title, labels, legends etc.

# %%
plt.figure()

#Creating x and y values
x = np.linspace(1,11,50)
y_best = ((2*x) + 4)
y = y_best + np.random.randint(-5,5,50)

#Creating a scatter plot of x and y values with 0.7 opacity
sca = plt.scatter(x,y, alpha = 0.7, c = "#558cf2")

#Creating a line plot of the best fit line
lin,  = plt.plot(x, y_best, "--r", linewidth = 2)
#plt.plot always returns a tuple of all the lines it plots (even if only 1 line is plotted)
#Hence the comma is added after lin to get the line2D object and not the tuple

#Adding x and y label
plt.xlabel("X Values")
plt.ylabel("Y Values")

#Adding a title
plt.title("Simple Best Fit Plot")

#Adding a legend
plt.legend([sca, lin], ["Scattered points", "Best fit line"])

#Adding grid with 0.5 opacity
plt.grid(alpha = 0.5)

# %% [markdown]
# This clearly looks better and presentable than the crude plots we were drawing previously. Each function here has many customizations of it's own and hence gives you an oppurtunity to unleash your creativity in the plots. There are various other commands to change ticks, ticklabels etc. Most people just find the necessary customization using a single Google Search hence there's no need to memorize any of these functions

# %% [markdown]
# <b>Note</b>: If you don't know what some of these terms mean, see the anatomy of a plot image above to get an idea.<br>
# Also note how better the process of plotting become by putting all the functions into a single cell.

# %% [markdown]
# matplotlib can also be used to plot various plots like histograms, bar graphs etc. which you might use a lot in the data analysis process. We'll be taking a look at some of them later.<br>

# %% [markdown]
# ### matplotlib styles

# %% [markdown]
# matplotlib comes with predefined styles which can be used to make you plots visually appealing.<br>
# You can use <code>plt.style.available</code> to get a list of all available styles and then apply a style using <code>plt.style.use('style_name')</code>

# %%
plt.style.available

# %% [markdown]
# Feel free to use a couple of styles and see the changes by running the below plot

# %%
plt.style.use('seaborn-white')

# %%
plt.figure(figsize = (6,6))

x = np.arange(1,366)
y1 = np.random.randn(365).cumsum(0)
y2 = np.random.randn(365).cumsum(0) + 20
y3 = np.random.randn(365).cumsum(0) - 20

plt.plot(x, y1, x, y2,x,y3); #Adding a semi-colon supresses unwanted output

# %% [markdown]
# ### Further Reading
# <b>For more applications and understanding of matplotlib check out this <a href = "https://matplotlib.org/tutorials/index.html">link</a> to the tutorials page on the official matplotlib website. It has tutorials and examples on topics ranging from basic to advanced.</b>

# %% [markdown]
# <hr style="height:2px;border-width:2;color:gray">

# %% [markdown]
# ## PANDAS VISUALIZATION

# %% [markdown]
# Pandas has the function <code>pd.DataFrame.plot()</code> which can be used to create various plots on a pandas Dataframe. Since it uses matplotlib to plot these, you can use matplotlib commands to customize the plots.<br>
# Let's begin by importing pandas.

# %%
import pandas as pd

# %% [markdown]
# We'll be using one of the most popular datasets in pattern recognition, <a href = "https://www.kaggle.com/arshid/iris-flower-dataset">the iris dataset</a> which can be loaded from <code>IRIS.csv</code>

# %%
#Loading the dataset
df = pd.read_csv("IRIS.csv")
df.head()

# %%
#Info on the dataset
df.info()

# %%
df.plot() #Creates a line plot of all columns

# %%
#Creating a scatter plot of sepal_width vs sepal_length of all species
df.plot("sepal_length", "sepal_width", kind = 'scatter', alpha = 0.5, c = 'Blue')

# %% [markdown]
# You can also use the plotting tools from pandas to draw various complicated plots using a single line of code.
# For example, a <a href = "https://datavizcatalogue.com/methods/parallel_coordinates.html">parallel coordinate plot</a> can be easily plotted as shown.

# %%
plt.figure()

#plotting this plot reveals that Iris-setosa can be distinguished from the other two using petal_length
pd.plotting.parallel_coordinates(df, 'species')

# %% [markdown]
# ### Further Reading

# %% [markdown]
# Refer to this <a href = "https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html">link</a> to learn more about visualzation in pandas.<br><a href = "https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.html">This</a> is the pandas documentation for <code>df.plot()</code>

# %% [markdown]
# <hr style="height:2px;border-width:2;color:gray">

# %% [markdown]
# ## SEABORN

# %% [markdown]
# Seaborn is a really powerful tool which used for making statistical graphics in Python. It is built on top of <b>matplotlib</b> and closely integrated with <b>pandas</b> data structures. Hence you can use the tools you already know to customize seaborn plots.<br>
# Let's begin by importing <code>seaborn</code> as <code>sns</code>. Since this is also an important Machine Learning and Data Analytics tool, it already comes with Anaconda and Colab.

# %%
import seaborn as sns

# %% [markdown]
# We'll just see an example plot in seaborn for now to understand how simple it can be to plot a complicated plot using seaborn.<br> We'll look at other functions later
# Let's plot a <a href = "https://seaborn.pydata.org/generated/seaborn.pairplot.html">pairplot</a> on the iris dataset.

# %%
#Plots every column against each other to identify correlations
fig = sns.pairplot(df, hue = 'species')

# %% [markdown]
# ### Further Reading

# %% [markdown]
# <a href = "https://seaborn.pydata.org/tutorial.html">This</a> is the link to the tutorial page on the official seaborn. Check this out for information on all kinds of statistical plots you can draw using seaborn.

# %% [markdown]
# <hr style="height:2px;border-width:2;color:gray">

# %% [markdown]
# ## SOME BASIC PLOTS

# %% [markdown]
# Now we'll see how to plot some basic and important plots using the tools you've learnt so far.<br>
# Note that we have already covered two such plots: <b>line plots</b> and <b>scatter plots</b><br><br>
# For the following examples we'll use the datasets already available in seaborn and can be accessed using <code>sns.load_dataset()</code>.

# %% [markdown]
# ### Bar Graphs
# A <b>bar graph</b> breaks categorical data down by group, and represents these amounts by using bars of different lengths. It uses either the number of individuals in each group (also called the frequency) or the percentage in each group (called the relative frequency).

# %%
#Loading the dataset
df = sns.load_dataset('tips')
df

# %%
#Plotting bar graph of total tips by day using pandas
plt.figure()

ser = df["tip"].groupby(df["day"]).sum()
ser.plot(kind = 'bar')

plt.title("Total tips by day")
plt.xlabel("Day")
plt.ylabel("Total tips");

# %%
#Plotting total bill by day using seaborn, it groups the y values by x values

plt.figure()
sns.barplot(x = "day", y = 'total_bill', data = df, capsize = 0.1, estimator = sum)

plt.title("Total bill by day")

#The seaborn plot also shows the 95% confidence interval by default

# %%
#Plots by nested grouping

plt.figure()
sns.barplot(x = 'day', y = 'total_bill', hue = 'sex', data = df, estimator = np.mean)

# %% [markdown]
# <b>Resources</b>:<br>
# <ul>
#     <li><a href = "https://matplotlib.org/3.2.1/api/_as_gen/matplotlib.pyplot.bar.html">matplotlib</a><br></li>
#     <li><a href = "https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.bar.html">pandas</a><br></li>
#     <li><a href = "https://seaborn.pydata.org/generated/seaborn.barplot.html">seaborn</a></li>
# </ul>

# %% [markdown]
# ### Histograms and Density plots

# %% [markdown]
# These plots are mainly used for univariate analysis.<br>
# A <b>histogram</b> is a kind of bar plot that gives a discretized display of value frequency. The data points are split into discrete, evenly spaced bins, and the number of data points in each bin is plotted.

# %%
#For histograms we shall plot normal distributions
x = np.random.randn(1000)

# %%
#Plotting a histogram using matplotlib
plt.figure()
plt.hist(x, bins = 50, edgecolor = 'black');
#Splits the data into 50 bins

# %%
#Plotting histogram using seaborn
plt.figure()
sns.distplot(x, kde = False, hist_kws = dict(edgecolor = 'k'));

# %% [markdown]
# A <b>density plot</b>, is formed by computing an estimate of a continuous probability distribution that might have generated the observed data.

# %%
#seaborn distplot by default fits a gaussian kernel density estimate to histogram
plt.figure()
sns.distplot(x);

# %% [markdown]
# <b>Resources</b>:<br>
# <ul>
#     <li><a href = "https://matplotlib.org/3.2.1/api/_as_gen/matplotlib.pyplot.hist.html">matplotlib</a><br></li>
#     <li><a href = "https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.hist.html">pandas</a><br></li>
#     <li><a href = "https://seaborn.pydata.org/generated/seaborn.distplot.html">seaborn</a></li>
# </ul>

# %% [markdown]
# ### Boxplots and Violinplots

# %% [markdown]
# In descriptive statistics, a <b>boxplot</b> is a method for graphically depicting groups of numerical data through their quartiles.

# %%
df

# %%
#Plotting a boxplot using seaborn
plt.figure()
sns.boxplot(x = 'total_bill', y = 'day', data = df)

# %% [markdown]
# A <b>violin plot</b> is similar to a box plot, with the addition of a rotated kernel density plot on each side.

# %%
plt.figure()
sns.violinplot(x="day", y="total_bill", data=df);

# %% [markdown]
# <b>Resources</b>:<br>
# <ul>
#     <li><a href = "https://seaborn.pydata.org/generated/seaborn.boxplot.html">boxplot</a></li>
#     <li><a href = "https://seaborn.pydata.org/generated/seaborn.violinplot.html">violinplot</a></li>
# </ul>

# %% [markdown]
# ### Heatmaps

# %% [markdown]
# A heatmap is a data visualization technique that shows magnitude of a phenomenon as color in two dimensions. A heatmap essentially represents 3D data on 2D space. It is one of the most widely used plots in data analysis.

# %%
#Loading the dataset
flight = sns.load_dataset('flights')
flight

# %%
#Creating a pivot table. Checkout df.pivot()
flight = flight.pivot("month", "year", "passengers")
flight

# %%
#Plotting the heatmap
plt.figure()
sns.heatmap(flight)

# %% [markdown]
# From the heatmap we can instanly notice the increase in passengers as years pass by. Aslso a general increase around the middle of the year.

# %% [markdown]
# <b>Resources</b>: <a href = "https://seaborn.pydata.org/generated/seaborn.heatmap.html">heatmap</a>

# %% [markdown]
# These are some of the basic plots commonly used in Data Analysis.

# %% [markdown]
# <hr style="height:2px;border-width:2;color:gray">

# %% [markdown]
# ## EXPLORATORY DATA ANALYSIS

# %% [markdown]
# <b>Exploratory Data Analysis (EDA) refers to the critical process of performing initial investigations on data so as to discover patterns,to spot anomalies,to test hypothesis and to check assumptions with the help of summary statistics and graphical representations.</b><br>
# This is one of the most important steps while doing a Machine Learning Project. It is the step where you truly understand the data that you are handling and draw useful insights from it. You use these insights to decide whether ML is going to be any use to this data or which ML model to fit to this data. The tools that you have learnt so far, mainly pandas and Visualization are used in the EDA process.<br>

# %% [markdown]
# <b>Check out this <a href = "https://towardsdatascience.com/exploratory-data-analysis-8fc1cb20fd15">link</a> to see an example EDA. I recommend you don't skip this link.</b>

# %% [markdown]
# EDA is something that you can't learn by reading. It is something that comes through experience just like visualization. Right now in your projects you may use simple plots. But as you do more and more projects and go through others', you'll learn and implement complicated techniques. So don't get discouraged if you don't remember most of the plotting functions, their attributes or different plots. It'll all come to you in due time.
